# %%
import pandas as pd

# %%
user_features = pd.read_csv("../dataset/user_features.csv")
user_features
# Out:
#        Unnamed: 0  site_idx  address  tourist_type like_type    targets  \
# 0               0         1       31             5    [4, 6]  [1, 8, 3]
# 1               1         1        3             5    [4, 6]     [1, 8]
# 2               2         1        6             3       [4]  [1, 2, 6]
# 3               3         1       28             4       [4]  [1, 2, 5]
# 4               4         1       29             3       [4]     [1, 2]
# ...           ...       ...      ...           ...       ...        ...
# 55851       55851      1000        9             3       [1]        [7]
# 55852       55852      1000        9             3       [1]        [7]
# 55853       55853      1000        9             5       [1]        [7]
# 55854       55854      1000       15             3       [1]        [7]
# 55855       55855      1000        9             3       [1]        [7]
#
#        price_sensitive     attention  label
# 0                    0  [3, 0, 2, 7]      1
# ...

# %%
site_idx_features = user_featus["site_idx"].copy()
site_idx_features[site_idx_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
address_features = user_featus['address'].copy()
address_features[address_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
tourist_type_features = user_features['tourist_type'].copy()
tourist_type_features[tourist_type_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
like_type_features = user_features["like_type"].copy()
like_type_features[like_type_features.isna()].copy()
# Out:
# Series([], Name: like_type, dtype: object)

# %%
targets_features = user_features["targets"].copy()
targets_features[targets_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
positive_sensitive_features = user_features["price_sensitive"].copy()
positive_sensitive_features[positive_sensitive_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
attention_features = user_features["attention"].copy()
attention_features[attention_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
label_features = user_features["label"].copy()
label_features[label_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
site_features = pd.read_pickle("../dataset/site_features.pkl")
site_features
# Out:
#      site_idx  score  hot_degree  address  \
# 0           1   0.96        1.00       29
# 1           2   0.94        1.00       29
# 2           3   0.96        1.00       31
# 3           4   0.94        1.00       20
# 4           5   0.94        1.00       33
# ..        ...    ...         ...      ...
# 995       996   0.86        0.68        7
# 996       997   0.92        0.68        6
# 997       998   0.88        0.68        2
# 998       999   0.92        0.68        6
# 999      1000   0.84        0.68        9
#
#                                        introduce_embed     price  \
# 0    [-0.037725143134593964, -0.12439101189374924, ...  0.000000
# 1    [-0.038046449422836304, -0.18526966869831085, ...  0.039503
# 2    [0.03834586590528488, -0.056213535368442535, 0...  0.000000
# 3    [0.009396699257194996, -0.23967264592647552, 0...  0.135440
# 4    [-0.046439655125141144, -0.17700868844985962, ...  0.603837
# ...

# %%
site_idx_features = site_features["site_idx"].copy()
site_idx_features[site_idx_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
score_features = site_features["score"].copy()
score_features[score_features.isna()].copy()
# Out:
# Series([], Name: score, dtype: float64)

# %%
hot_degree_features = site_features["hot_degree"].copy()
hot_degree_features[hot_degree_features.isna()].copy()
# Out:
# Series([], Name: hot_degree, dtype: float64)

# %%
address_features = site_features["address"].copy()
address_features[address_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
introduce_features = site_features["introduce_embed"].copy()
introduce_features[introduce_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
price_features = site_features["price"].copy()
price_features[price_features.isna()].index
# Out:
# Index([], dtype='int64')

# %%
positive_comment_rate = site_features["positive_comment_rate"].copy()
positive_comment_rate[positive_comment_rate.isna()].index
# Out:
# Index([102, 132, 195, 198, 220, 238, 268, 287, 295, 299, 306, 319, 333, 365,
#        384, 441, 445, 446, 460, 468, 479, 484, 490, 498, 509, 552, 579, 582,
#        591, 606, 613, 622, 627, 635, 643, 667, 672, 687, 710, 730, 744, 750,
#        756, 779, 799, 801, 811, 815, 825, 831, 849, 872, 879, 894, 900, 914,
#        915, 925, 933, 943, 953, 967, 977, 988, 991],
#       dtype='int64')

# %%
positive_comment_rate[102]
# Out:
# np.float64(nan)

# %%
positive_comment = pd.read_csv('../dataset/tb_positive_comment_extra2.csv')
positive_comment
# Out:
#           id  site_idx                                            content  \
# 0          1         1  我会再推荐大家去故宫博物院的，因为我因为武英殿的瓷器展时间过于长了，没赶上故宫的下午茶，下次...
# 1          2         1  陶瓷馆\n一上来就选择游中轴线的游客永远不会到达的一个地方，位于故宫午门进入后西侧的武英殿。...
# 2          3         1  故宫，一眼千年的历史回响\n\n踏入故宫的那一刻，时间仿若倒流，历史的厚重感扑面而来。这座屹...
# 3          4         1  踏入北京故宫，仿若步入历史长河、巍峨宫殿气势恢宏，一砖一瓦皆是岁月沉淀。中轴线上，太和殿庄严...
# 4          5         1  故宫博物院作为古代皇宫在世界上是独一无二的。它不同于法爱丽舍宫及俄克林姆林宫，它是以木构为主...
# ...      ...       ...                                                ...
# 95155  95156      1000  去厦门出差，住在了双子塔这里的酒店，这里是两栋300米高的摩天大楼以及裙楼组成，是厦门第二高...
# 95156  95157      1000  双子塔虽然没有上去，但是在里面吃了铁板海鲜买了水果跟零食！发现一个可以看海景吃饭的地方！夜景...
# 95157  95158      1000  厦门双子塔作为当地的著名地标建筑，沿着环岛路的海滨步道一路走，都可以远远望见这两座建筑物。双...
# 95158  95159      1000  双子塔作为厦门市的地标建筑，是来自各地的游客不可避免也难以错过的一个景点。观看双子塔，有两个...
# 95159  95160      1000                          两座塔组成的双子塔，可以上最上面观景台看厦门的景色
#
#       tourist_type   ip
# 0             朋友出游   上海
# 1             朋友出游   辽宁
# ...

# %%
negative_comment = pd.read_csv('../dataset/tb_negative_comment_extra.csv')

# %%
negative_comment
# Out:
#           id  site_idx                                            content  \
# 0          1         1                             根据票据,我们没有去博物馆,博物馆说钱还回去
# 1          2         1  当我的身份证被拒绝时,在入口门口有头发提升的经验。博物馆工作人员说我的票被退款了。此外,包括...
# 2          3         1  头一天打电话说铛铛车没组成团，说后面联系退钱，早上自己去国博无导游无接送，下午有导游说一点午...
# 3          4         1           这是我第一次去中国的地方,禁城根本没有印象,一切都一样,几分钟后,兴趣完全消失了
# 4          5         1                                              不愿置评！
# ...      ...       ...                                                ...
# 40927  40928      1000  买好票以后发的短信没有二维码 写着需要取票 去窗口排队了半天以后说现在非游玩项目都不需要取票...
# 40928  40929      1000                                             千万别去这里
# 40929  40930      1000                                              千万别上去
# 40930  40931      1000  最坑人的一个景点，也不知道这些想赚钱的人是怎么想的！！！门票180元到58层给你一个不足10...
# 40931  40932      1000  现场没有卖学生票，只有在携程上购买。上观光塔前有几个像打暑期工的人拉住我们说，免费拍摄，包含...
#
#       tourist_type  ip
# 0             家庭亲子  未知
# 1             家庭亲子  未知
# ...

# %%
positive_comment[positive_comment['site_idx'] == 102]
# Out:
#           id  site_idx                                            content  \
# 10100  10101       102  钟鼓索道位于国家5A级风景名胜区——万石植物园的西侧，全长1000多米，全程约40分钟，离地...
# 10101  10102       102  提前上网搜了一下，感觉褒贬不一，但是真的去了以后超级推荐啊，半边城市半边大海，微风不燥，春暖...
# 10102  10103       102  缆车80元，最好网上提前点买，特别是要拍落日余晖的小伙伴可以在网上提前预约，因为很多游客都是...
# 10103  10104       102  索道没有单程，只有往返全程，40分钟。起点在厦门森林公园西门，半程终点大概快到南普陀寺的五老...
# 10104  10105       102  厦门钟鼓索道在厦门植物园西侧，全长1千多米。只有往返票(80元)，中途不能下缆车，原路返回。...
# ...      ...       ...                                                ...
# 10195  10196       102  能俯瞰部分福建城市景观，尤其是能看到双子塔。建议第一站去钟鼓索道，因为人少天凉快，要是过了上...
# 10196  10197       102  从植物园西门出来后，左手边有个类似岗亭位置的走上去就是了 ，建议可以此处安排明显标识标牌！\...
# 10197  10198       102  2019 热爱生活  \n️各种节日快乐️\n快乐的人儿，每天都是节日‍♀️\n&amp;#...
# 10198  10199       102  果然4点~5点的是最紧俏的，但是景色也非常值得。走到2楼换了票就可以准备排队啦，大家最好在想...
# 10199  10200       102  为了到这个索道走的累死，从中山路步行街走到索道至少半小时多，但是这个索道真心要做，他是镂空的...
#
#       tourist_type   ip
# 10100         情侣夫妻   福建
# 10101         家庭亲子   天津
# ...

# %%
negative_comment[negative_comment['site_idx'] == 102]
# Out:
#         id  site_idx                                            content  \
# 5050  5051       102  一、建议携程对供应商的服务质量严格加强平台方监管。二、建议加强索道售票处人员培训管理，尤其是...
# 5051  5052       102                                              体验感极差
# 5052  5053       102                                      别浪费钱 一般般 不如洗脚
# 5053  5054       102                   两个人160元就是拍几张照片，别的啥也没有。\n价值160的照片
# 5054  5055       102  还行 就是体重偏重的只能单人乘坐 两个人不能超350斤  这个缆车还没广东长龙隆动物园的大 ...
# 5055  5056       102                                           不值得，太危险了
# 5056  5057       102                                             没什么意思。
# 5057  5058       102                                          不值得去，没啥景色
# 5058  5059       102  我们9早上最早的票 按时到达之后才通知要临时维修1-2小时 行李也不让提前寄存 没有任何补救...
# 5059  5060       102                                          导游比我还来的晚。
# 5060  5061       102                                            很不好，不开心
# 5061  5062       102  风景是不错！但建议2人同行，9/20当天其实没有太多人去搭乘，我只有一个人，他会说要2人一起...
# ...

# %%
comment_feautures = pd.read_csv('../dataset/comment_dataset.csv')

# %%
comment_feautures
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  site_idx  ip tourist_type  \
# 0                 0             0           0         1  上海         朋友出游
# 1                 1             1           1         1  辽宁         朋友出游
# 2                 2             2           2         1  江苏         家庭亲子
# 3                 3             3           3         1  新疆         情侣夫妻
# 4                 4             4           4         1  北京         家庭亲子
# ...             ...           ...         ...       ...  ..          ...
# 55851         55851            55          10      1000  福建         家庭亲子
# 55852         55852            56          11      1000  福建         家庭亲子
# 55853         55853            57          12      1000  福建         朋友出游
# 55854         55854            58          13      1000  广东         家庭亲子
# 55855         55855            59          14      1000  福建         家庭亲子
#
#       likeType targets priceSensitive attention  label
# ...

# %%
tb_site_extra = pd.read_csv('../dataset/tb_site_extra.csv')

# %%
tb_site_extra
# Out:
#        id  site_idx  price  positive_comment_count  negative_comment_count
# 0       1         1      0                  115456                    2063
# 1       2         2     35                   39623                    1154
# 2       3         3      0                  128468                     668
# 3       4         4    120                   83931                    3747
# 4       5         5    535                   37770                    1046
# ..    ...       ...    ...                     ...                     ...
# 995   996       996     50                     749                      67
# 996   997       997    158                    3482                      85
# 997   998       998      0                     478                      46
# 998   999       999    380                     938                      28
# 999  1000      1000      0                     514                      71
#
# [1000 rows x 5 columns]

# %%
tb_site_extra.iloc[132]
# Out:
# id                        133
# site_idx                  133
# price                       0
# positive_comment_count      0
# negative_comment_count      0
# Name: 132, dtype: int64

# %%
mean_rate = site_features["positive_comment_rate"].mean()
mean_rate
# Out:
# np.float64(0.9508691032151143)

# %%
site_features["positive_comment_rate"] = site_features["positive_comment_rate"].fillna(mean_rate)

# %%
site_features
# Out:
#      site_idx  score  hot_degree  address  \
# 0           1   0.96        1.00       29
# 1           2   0.94        1.00       29
# 2           3   0.96        1.00       31
# 3           4   0.94        1.00       20
# 4           5   0.94        1.00       33
# ..        ...    ...         ...      ...
# 995       996   0.86        0.68        7
# 996       997   0.92        0.68        6
# 997       998   0.88        0.68        2
# 998       999   0.92        0.68        6
# 999      1000   0.84        0.68        9
#
#                                        introduce_embed     price  \
# 0    [-0.037725143134593964, -0.12439101189374924, ...  0.000000
# 1    [-0.038046449422836304, -0.18526966869831085, ...  0.039503
# 2    [0.03834586590528488, -0.056213535368442535, 0...  0.000000
# 3    [0.009396699257194996, -0.23967264592647552, 0...  0.135440
# 4    [-0.046439655125141144, -0.17700868844985962, ...  0.603837
# ...

# %%
positive_comment_rate = site_features["positive_comment_rate"]
positive_comment_rate[positive_comment_rate.isna()].index
# Out:
# Index([], dtype='int64')

# %%
site_features.to_pickle('../dataset/site_features.pkl')

# %%
site_features = pd.read_pickle('../dataset/site_features.pkl')
